# %%
import pandas as pd

train = pd.read_csv(r"C:\Users\aadhitya98\Downloads\train.csv")
test = pd.read_csv(r"C:\Users\aadhitya98\Downloads\test.csv")

# %%
train.head(80)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
def bargraph(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bargraph('Sex')

# %%
bargraph('Pclass')

# %%
bargraph('SibSp')

# %%
bargraph('Parch')

# %%
bargraph('Embarked')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ###  Name

# %%
combine = [train, test] 

for datat in combine:
    datat['Title'] = datat['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Jonkheer      1
# Lady          1
# Don           1
# Capt          1
# Mme           1
# Countess      1
# Sir           1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Rev         2
# Col         2
# Dona        1
# Ms          1
# Dr          1
# Name: Title, dtype: int64

# %%
titlemap = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for datat in combine:
    datat['Title'] = datat['Title'].map(titlemap)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
bargraph('Title')

# %%
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %% [markdown]
# ### Sex

# %%
sexmap = {"male": 0, "female": 1}
for datat in combine:
    datat['Sex'] = datat['Sex'].map(sexmap)

# %%
bargraph('Sex')

# %% [markdown]
# ###  Age

# %%
train.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex    Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.00      1      0         A/5 21171
# 1             2         1       1    1  38.00      1      0          PC 17599
# 2             3         1       3    1  26.00      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.00      1      0            113803
# 4             5         0       3    0  35.00      0      0            373450
# 5             6         0       3    0    NaN      0      0            330877
# 6             7         0       1    0  54.00      0      0             17463
# 7             8         0       3    0   2.00      3      1            349909
# 8             9         1       3    1  27.00      0      2            347742
# 9            10         1       2    1  14.00      1      0            237736
# 10           11         1       3    1   4.00      1      1           PP 9549
# ...

# %%
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
train.head(30)
train.groupby("Title")["Age"].transform("median")
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
# 5      30.0
# 6      30.0
# 7       9.0
# 8      35.0
# 9      35.0
# 10     21.0
# 11     21.0
# 12     30.0
# 13     30.0
# 14     21.0
# 15     35.0
# 16      9.0
# 17     30.0
# 18     35.0
# 19     35.0
# 20     30.0
# 21     30.0
# 22     21.0
# 23     30.0
# 24     21.0
# 25     35.0
# 26     30.0
# 27     30.0
# 28     21.0
# 29     30.0
#        ...
# 861    30.0
# 862    35.0
# 863    21.0
# 864    30.0
# 865    35.0
# 866    21.0
# 867    30.0
# 868    30.0
# 869     9.0
# 870    30.0
# 871    35.0
# 872    30.0
# 873    30.0
# 874    35.0
# 875    21.0
# 876    30.0
# 877    30.0
# 878    30.0
# 879    35.0
# 880    35.0
# 881    30.0
# 882    21.0
# 883    30.0
# 884    30.0
# 885    35.0
# 886     9.0
# 887    21.0
# 888    21.0
# 889    30.0
# 890    30.0
# Name: Age, Length: 891, dtype: float64

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(20, 30)
# Out:
# (20, 30)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(30, 40)
# Out:
# (30, 40)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40, 60)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40, 60)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(60)
# Out:
# (60, 80.0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Title          418 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %%
for data in combine:
    data.loc[ data['Age'] <= 16, 'Age'] = 0,
    data.loc[(data['Age'] > 16) & (data['Age'] <= 26), 'Age'] = 1,
    data.loc[(data['Age'] > 26) & (data['Age'] <= 36), 'Age'] = 2,
    data.loc[(data['Age'] > 36) & (data['Age'] <= 62), 'Age'] = 3,
    data.loc[ data['Age'] > 62, 'Age'] = 4

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  0.0      1      0         A/5 21171
# 1            2         1       1    1  0.0      1      0          PC 17599
# 2            3         1       3    1  0.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  0.0      1      0            113803
# 4            5         0       3    0  0.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
bargraph('Age')

# %% [markdown]
# ###  Embarked

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
for datat in combine:
    datat['Embarked'] = datat['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  0.0      1      0         A/5 21171
# 1            2         1       1    1  0.0      1      0          PC 17599
# 2            3         1       3    1  0.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  0.0      1      0            113803
# 4            5         0       3    0  0.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
embarkedmap = {"S": 0, "C": 1, "Q": 2}
for datat in combine:
    datat['Embarked'] = datat['Embarked'].map(embarkedmap)

# %% [markdown]
# ###  Fare

# %%
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  0.0      1      0         A/5 21171
# 1             2         1       1    1  0.0      1      0          PC 17599
# 2             3         1       3    1  0.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  0.0      1      0            113803
# 4             5         0       3    0  0.0      0      0            373450
# 5             6         0       3    0  0.0      0      0            330877
# 6             7         0       1    0  0.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  0.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# ...

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
 
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 30)
# Out:
# (0, 30)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 512.3292)

# %%
for datat in combine:
    datat.loc[ datat['Fare'] <= 17, 'Fare'] = 0,
    datat.loc[(datat['Fare'] > 17) & (datat['Fare'] <= 30), 'Fare'] = 1,
    datat.loc[(datat['Fare'] > 30) & (datat['Fare'] <= 100), 'Fare'] = 2,
    datat.loc[ datat['Fare'] > 100, 'Fare'] = 3

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  0.0      1      0         A/5 21171
# 1            2         1       1    1  0.0      1      0          PC 17599
# 2            3         1       3    1  0.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  0.0      1      0            113803
# 4            5         0       3    0  0.0      0      0            373450
#
#    Fare Cabin  Embarked  Title
# 0   0.0   NaN         0      0
# 1   2.0   C85         1      2
# 2   0.0   NaN         0      1
# 3   2.0  C123         0      2
# 4   0.0   NaN         0      0

# %% [markdown]
# ### Cabin

# %%
train.Cabin.value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# C22 C26        3
# E101           3
# F2             3
# F33            3
# D              3
# C83            2
# D20            2
# D35            2
# E24            2
# C126           2
# C78            2
# C92            2
# D36            2
# B77            2
# C125           2
# E33            2
# C124           2
# B35            2
# E25            2
# E67            2
# F4             2
# C68            2
# E121           2
# B51 B53 B55    2
# B22            2
# B5             2
# C93            2
#               ..
# C111           1
# C90            1
# T              1
# C101           1
# C50            1
# B30            1
# C99            1
# A10            1
# B79            1
# D7             1
# A23            1
# C86            1
# D19            1
# D46            1
# C118           1
# C128           1
# B94            1
# C95            1
# E31            1
# F E69          1
# A20            1
# ...

# %%
for datat in combine:
    datat['Cabin'] = datat['Cabin'].str[:1]

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
cabinmap = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for datat in combine:
    datat['Cabin'] = datat['Cabin'].map(cabinmap)

# %%
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %% [markdown]
# ### FamilySize

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 11.0)

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  0.0      1      0         A/5 21171
# 1            2         1       1    1  0.0      1      0          PC 17599
# 2            3         1       3    1  0.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  0.0      1      0            113803
# 4            5         0       3    0  0.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title  FamilySize
# 0   0.0    2.0         0      0           2
# 1   2.0    0.8         1      2           2
# 2   0.0    2.0         0      1           1
# 3   2.0    0.8         0      2           2
# 4   0.0    2.0         0      0           1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  0.0      1      0         A/5 21171
# 1            2         1       1    1  0.0      1      0          PC 17599
# 2            3         1       3    1  0.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  0.0      1      0            113803
# 4            5         0       3    0  0.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title  FamilySize
# 0   0.0    2.0         0      0           2
# 1   2.0    0.8         1      2           2
# 2   0.0    2.0         0      1           1
# 3   2.0    0.8         0      2           2
# 4   0.0    2.0         0      0           1

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0       3    0  0.0   0.0    2.0         0      0           2
# 1       1    1  0.0   2.0    0.8         1      2           2
# 2       3    1  0.0   0.0    2.0         0      1           1
# 3       1    1  0.0   2.0    0.8         0      2           2
# 4       3    0  0.0   0.0    2.0         0      0           1
# 5       3    0  0.0   0.0    2.0         2      0           1
# 6       1    0  0.0   2.0    1.6         0      0           1
# 7       3    0  0.0   1.0    2.0         0      3           5
# 8       3    1  0.0   0.0    2.0         0      2           3
# 9       2    1  0.0   2.0    1.8         1      2           2

# %% [markdown]
# ##  Modelling

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# Survived      891 non-null int64
# Pclass        891 non-null int64
# Sex           891 non-null int64
# Age           891 non-null float64
# Fare          891 non-null float64
# Cabin         891 non-null float64
# Embarked      891 non-null int64
# Title         891 non-null int64
# FamilySize    891 non-null int64
# dtypes: float64(3), int64(6)
# memory usage: 62.7 KB

# %% [markdown]
# ###  Cross Validation (K-fold)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# ###  kNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.81111111 0.80898876 0.80898876 0.84269663 0.87640449 0.78651685
#  0.82022472 0.7752809  0.82022472 0.80898876]

# %%
round(np.mean(score)*100, 2)
# Out:
# 81.59

# %% [markdown]
# ### Decision Tree

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.76666667 0.83146067 0.7752809  0.7752809  0.8988764  0.7752809
#  0.83146067 0.82022472 0.74157303 0.79775281]

# %%
round(np.mean(score)*100, 2)
# Out:
# 81.59

# %% [markdown]
# ### Random Forest

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.83333333 0.80898876 0.78651685 0.80898876 0.86516854 0.78651685
#  0.84269663 0.82022472 0.75280899 0.83146067]

# %%
round(np.mean(score)*100, 2)
# Out:
# 81.37

# %% [markdown]
# ###  Naive Bayes

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.84444444 0.73033708 0.74157303 0.74157303 0.70786517 0.80898876
#  0.74157303 0.79775281 0.86516854 0.82022472]

# %%
round(np.mean(score)*100, 2)
# Out:
# 78.0

# %% [markdown]
# ###  SVM

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.83333333 0.79775281 0.83146067 0.82022472 0.83146067 0.82022472
#  0.82022472 0.84269663 0.84269663 0.86516854]

# %%
round(np.mean(score)*100,2)
# Out:
# 83.05

# %% [markdown]
# ##  Testing

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-183-d7af980d6178> in <module>()
#       4     })
#       5
# ----> 6 submission.to_csv('submission.csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     134             f, handles = _get_handle(self.path_or_buf, self.mode,
# ...

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
